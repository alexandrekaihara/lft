# %%
from pathlib import Path

BASE = Path.cwd() # .../dash_topology/notebooks
DATADIR_ROOT = BASE.parent / "datadir"

print("Notebook cwd:", BASE)
print("Datadir root:", DATADIR_ROOT)
print("Exists?", DATADIR_ROOT.exists())

runs = sorted(DATADIR_ROOT.glob("run_*"))
print("Runs:", [p.name for p in runs])
# Out:
# Notebook cwd: /home/arthur.barbabella/lft/onos_topologies/dash_topology/notebooks
# Datadir root: /home/arthur.barbabella/lft/onos_topologies/dash_topology/datadir
# Exists? True
# Runs: ['run_2025-11-21_10-30-44', 'run_2025-11-25_10-34-53', 'run_2025-11-25_18-47-25', 'run_2025-11-28_16-11-59', 'run_2025-11-28_16-43-34']

# %%
RUN_ROOT = runs[-1] # get last run

print("Using RUN_ROOT:", RUN_ROOT)

iters = sorted(RUN_ROOT.glob("iter_*"))
print("Iterations found:", len(iters))
iters[:3]
# Out:
# Using RUN_ROOT: /home/arthur.barbabella/lft/onos_topologies/dash_topology/datadir/run_2025-11-28_16-43-34
# Iterations found: 3
# [PosixPath('/home/arthur.barbabella/lft/onos_topologies/dash_topology/datadir/run_2025-11-28_16-43-34/iter_0000'),
#  PosixPath('/home/arthur.barbabella/lft/onos_topologies/dash_topology/datadir/run_2025-11-28_16-43-34/iter_0001'),
#  PosixPath('/home/arthur.barbabella/lft/onos_topologies/dash_topology/datadir/run_2025-11-28_16-43-34/iter_0002')]

# %%
import gzip, json
import pandas as pd

def read_client_gz(path: Path):
    with gzip.open(path, "rt", encoding="utf-8") as f:
        data = json.load(f)

    # formato 1: lista direta
    if isinstance(data, list):
        return data

    # formato 2: dict com "client"
    if isinstance(data, dict):
        return data.get("client", [])

    return []

# %%
records = []

for iter_path in iters:
    iter_name = iter_path.name # iter_0000, iter_0001...
    clients_dir = iter_path / "clients"

    for gz_file in sorted(clients_dir.glob("*.json.gz")):
        cname = gz_file.name.replace(".json.gz", "") # cl0, cl1...
        rows = read_client_gz(gz_file)

        for r in rows:
            r2 = dict(r)
            r2["iter_round"] = iter_name
            r2["client"] = cname
            records.append(r2)

df = pd.DataFrame(records)
print("rows:", len(df))
df["round_idx"] = df["iter_round"].str.extract(r"iter_(\d+)").astype(int)
df.head(15)
# Out:
# rows: 870
#     connect_time  delta_sys_time  delta_user_time   elapsed  elapsed_target  \
# 0              0               0                0  0.718812               2
# 1              0               0                0  1.795089               2
# 2              0               0                0  1.999487               2
# 3              0               0                0  1.998982               2
# 4              0               0                0  1.993348               2
# 5              0               0                0  2.005202               2
# 6              0               0                0  2.004429               2
# 7              0               0                0  1.993471               2
# 8              0               0                0  2.004030               2
# 9              0               0                0  1.993113               2
# 10             0               0                0  1.999546               2
# ...

# %%
import matplotlib.pyplot as plt 
import matplotlib.ticker as mticker

# ensure ordering
tmp = df.sort_values(["round_idx", "client", "iteration"]).copy()

# last rate per client in each round/run
last_per_client = tmp.groupby(["round_idx", "client"], as_index=False).tail(1)

# average across clients (one point per round)
g = last_per_client.groupby("round_idx")["rate"].mean().reset_index()
g["rate_mbps"] = g["rate"] / 1000.0  # kbit/s -> Mbps

x = g["round_idx"].astype(int)

plt.figure()
plt.plot(x, g["rate_mbps"], marker="o")
plt.xlabel("Rodada (round_idx)")
plt.ylabel("Rate final médio (Mbps)")
plt.title("Rate final por rodada (média do último rate de cada cliente)")
plt.grid(True)

ax = plt.gca()
ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))
plt.xticks(x)
plt.show()

# %%
pivot = df.pivot_table(index="client", columns="round_idx", values="rate", aggfunc="mean")

plt.figure(figsize=(12,6))
plt.imshow(pivot, aspect="auto")
plt.colorbar(label="Mbps")
plt.xticks(range(len(pivot.columns)), pivot.columns)
plt.yticks(range(len(pivot.index)), pivot.index)
plt.xlabel("Rodada (round_idx)")
plt.ylabel("Cliente")
plt.title("Rede: heatmap do throughput medido (Mbps) por cliente/rodada")
plt.show()

# %%
g = df.groupby("round_idx")["received"].sum().reset_index()
x = g["round_idx"].astype(int)

plt.figure()
plt.plot(x, g["received"], marker="o")
plt.xlabel("Rodada (round_idx)")
plt.ylabel("Bytes totais recebidos (soma)")
plt.title("Rede: volume total baixado por rodada")
plt.grid(True)
ax = plt.gca()
ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))
plt.xticks(x)
plt.show()

# %%
g = df.groupby("round_idx")["elapsed"].mean().reset_index()
x = g["round_idx"].astype(int)

plt.figure()
plt.plot(x, g["elapsed"], marker="o")
plt.axhline(2.0, linestyle="--")
plt.xlabel("Rodada (round_idx)")
plt.ylabel("Elapsed médio (s)")
plt.title("Download time: elapsed médio por rodada (linha = 2s)")
plt.grid(True)
ax = plt.gca()
ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))
plt.xticks(x)
plt.show()
